# %%
summary_all = {}

hotels_sweep = [542., 543., 545., 546., 547., 548., 549., 550., 551., 552., 554., 555., 643., 956., 957., 960.]

for hotel_sel in hotels_sweep:

    # %run nb0_arr_analysis.ipynb
    
    summary_all[hotel_sel] = summary_df
# Out:
# /usr/local/lib/python3.7/site-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm
# Hotels:
# [542. 543. 545. 546. 547. 548. 549. 550. 551. 552. 554. 555. 643. 956.
#  957. 960.]
#
# Selected: 542.0
#
# reservations_df shape: (92634, 19)
#                    plan_desc    RoomTypes_desc  market_segment_bi_id  \
# res_date
# 2018-10-10  breakfast  board  deluxe carmel&se                   4.0
# 2018-10-30  breakfast  board   deluxe bay view                   4.0
# 2018-10-30  breakfast  board   deluxe bay view                   4.0
# 2018-10-12  breakfast  board  deluxe carmel&se                   4.0
# 2018-10-11  breakfast  board  deluxe carmel&se                   4.0
#
#             MainCust source sales_channel club_code StatisticSource  \
# res_date
# 2018-10-10    1402.0   t.a.     home site
# 2018-10-30    2837.0   t.a.     home site
# ...

# %%
for hotel_sel in hotels_sweep:
    
    print('Hotel %.2f' % hotel_sel)
    display(summary_all[hotel_sel])
    print('\n\n')
# Out:
# Hotel 542.00
#                         train_accuracy  test_accuracy
# linear_regressor                0.5060         0.0000
# ridge_regressor                 0.5077         0.5161
# lasso_regressor                 0.5076         0.5162
# elasticnet_regressor            0.4752         0.4817
# supportvect_regressor           0.4830         0.4893
# decisiontree_regressor          0.9127         0.7209
# randomforest_regressor          0.2815         0.3020
# xgboost_regressor               0.6819         0.6804
# mlp_regressor                   0.8248         0.0000
# Hotel 543.00
#                         train_accuracy  test_accuracy
# linear_regressor                0.4703         0.0000
# ridge_regressor                 0.4704         0.4775
# lasso_regressor                 0.4703         0.4773
# elasticnet_regressor            0.4394         0.4410
# supportvect_regressor           0.4334         0.4426
# decisiontree_regressor          0.8922         0.6964
# ...

# %%
print('Completed')
# Out:
# Completed
